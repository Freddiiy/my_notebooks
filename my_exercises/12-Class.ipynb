# %% [markdown]
# # steps
#
# ### Part 1
# 1. Get data from: "https://en.wikisource.org/wiki/Portal:State_of_the_Union_Speeches_by_United_States_Presidents"
# 2. Using BeatifullSoup get all the speeches from 1900-2022
# 3. Load all speech urls into a dictionary with year as key. Hint (get year with regex: `r"\b(19|20)\d{2}\b"`)
# 4. Loop through dictionary and save content of each speech in [year].txt files
#
# ### Part 2
# 1. Install nltk: `pip install nltk`
# 2. From the data/gdp.csv file create a dataframe with year and GDP
# 3. From the data/US presidents.csv file create a dataframe with year, president and party
# 4. From the developed text files in part 1, create a dictionary with year:speech
# 5. Clean text by change all to lowercase and remove '\n'
# 6. Get words from texts (from nltk.tokenize import word_tokenize). Clean text by removing stop words (from nltk.corpus import stopwords) and all non-alphabetic characters (including , and .)
# 7. Use from nltk.stem import WordNetLemmatizer to lemmatize all texts
#
# ### Part 3
# **[TextBlob](https://textblob.readthedocs.io/en/dev/quickstart.html)** returns polarity and subjectivity of a sentence. Polarity lies between [-1,1], -1 defines a negative sentiment and 1 defines a positive sentiment. Subjectivity quantifies the amount of personal opinion and factual information contained in the text. The higher subjectivity means that the text contains personal opinion rather than factual information
# 1. Install both textblob for sentiment analysis and wordclouds (pip install textblob wordclouds) and download the vader lexicon (nltk.download('vader_lexicon'))
# 2. Find the polarity and subjectivity of each text (Hint: `TextBlob(text).sentiment`)
# 3. Is there a correlation between negativity and recession years?
# 4. Create a word cloud for the cleaned up speeches of both Trump and Obama. What can be learned from the word clouds?

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
def save_speeches():
    res = requests.get("https://en.wikisource.org/wiki/Portal:State_of_the_Union_Speeches_by_United_States_Presidents")
    res.raise_for_status()

    soup = BeautifulSoup(res.text, "lxml")
    links = soup.find_all("a")

    year_dict = dict()
    for i in links:
        if str(i.get("href")).startswith("/wiki/") and re.search(r"\b(19|20)\d{2}\b", i.parent.text):
            year = re.findall(r"\b\d{4}\b", i.parent.text)[0]
            link_child = i.parent.find("a").get("href")
            abs_link = f"https://en.wikisource.org{link_child}"
            year_dict[year] = abs_link

    for k, v in year_dict.items():
        speech = ""
        s_res = requests.get(v)
        s_res.raise_for_status()

        speech_soup = BeautifulSoup(s_res.text, "lxml")
        speech_parts = speech_soup.find_all("p")
        for s in speech_parts:
            speech += f"{s.text}"

        with open(f"../my_data/speeches/{k}.txt", "w+") as file:
            print(f"Writing {k}.txt")
            file.write(f"{k}: {speech}")


save_speeches()
# Out:
# Writing 1900.txt
# Writing 1901.txt
# Writing 1902.txt
# Writing 1903.txt
# Writing 1904.txt
# Writing 1905.txt
# Writing 1906.txt
# Writing 1907.txt
# Writing 1908.txt
# Writing 1909.txt
# Writing 1910.txt
# Writing 1911.txt
# Writing 1912.txt
# Writing 1913.txt
# Writing 1914.txt
# Writing 1915.txt
# Writing 1916.txt
# Writing 1917.txt
# Writing 1918.txt
# Writing 1919.txt
# Writing 1920.txt
# Writing 1921.txt
# Writing 1922.txt
# Writing 1923.txt
# Writing 1924.txt
# Writing 1925.txt
# Writing 1926.txt
# Writing 1927.txt
# Writing 1928.txt
# Writing 1929.txt
# Writing 1930.txt
# Writing 1931.txt
# Writing 1932.txt
# Writing 1934.txt
# Writing 1935.txt
# Writing 1936.txt
# Writing 1937.txt
# Writing 1938.txt
# Writing 1939.txt
# Writing 1940.txt
# Writing 1941.txt
# Writing 1942.txt
# Writing 1943.txt
# Writing 1944.txt
# Writing 1945.txt
# Writing 1946.txt
# Writing 1947.txt
# Writing 1948.txt
# Writing 1949.txt
# Writing 1950.txt
# Writing 1951.txt
# Writing 1952.txt
# Writing 1953.txt
# Writing 1954.txt
# Writing 1955.txt
# Writing 1956.txt
# Writing 1957.txt
# Writing 1958.txt
# Writing 1959.txt
# Writing 1960.txt
# Writing 1961.txt
# Writing 1962.txt
# Writing 1963.txt
# Writing 1964.txt
# Writing 1965.txt
# Writing 1966.txt
# Writing 1967.txt
# Writing 1968.txt
# Writing 1969.txt
# Writing 1970.txt
# Writing 1971.txt
# Writing 1972.txt
# Writing 1973.txt
# Writing 1974.txt
# Writing 1975.txt
# Writing 1976.txt
# Writing 1977.txt
# Writing 1978.txt
# Writing 1979.txt
# Writing 1980.txt
# Writing 1981.txt
# Writing 1982.txt
# Writing 1983.txt
# Writing 1984.txt
# Writing 1985.txt
# Writing 1986.txt
# Writing 1987.txt
# Writing 1988.txt
# Writing 1989.txt
# Writing 1990.txt
# Writing 1991.txt
# Writing 1992.txt
# Writing 1993.txt
# Writing 1994.txt
# Writing 1995.txt
# Writing 1996.txt
# Writing 1997.txt
# Writing 1998.txt
# Writing 1999.txt
# Writing 2000.txt
# Writing 2001.txt
# Writing 2002.txt
# Writing 2003.txt
# Writing 2004.txt
# Writing 2005.txt
# Writing 2006.txt
# Writing 2007.txt
# Writing 2008.txt
# Writing 2009.txt
# Writing 2010.txt
# Writing 2011.txt
# Writing 2012.txt
# Writing 2013.txt
# Writing 2014.txt
# Writing 2015.txt
# Writing 2016.txt
# Writing 2017.txt
# Writing 2018.txt
# Writing 2019.txt
# Writing 2020.txt
# Writing 2021.txt
# Writing 2022.txt
